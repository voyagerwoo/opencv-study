# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image

im = cv2.imread('contour_test.jpg')
imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
im2, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

plt.imshow(imgray)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-f020bcbfb567> in <module>()
#       5
#       6 im = cv2.imread('contour_test.jpg')
# ----> 7 imgray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
#       8 ret,thresh = cv2.threshold(imgray,127,255,0)
#       9 im2, contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/color.cpp:11111: error: (-215) scn == 3 || scn == 4 in function cvtColor

# %%
cv2.drawContours(im, contours, -1, (0,255,0), 3)
plt.imshow(im)
plt.show()

im_to_save = Image.fromarray(im)
im_to_save.save('draw_contours.jpg', "JPEG")
